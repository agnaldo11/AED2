# %%
def barata_quente(nomes, Max):
    #Criar e popular a fila. 
    file = Queue()
    for nome in nomes: 
        file.enqueue(nome)
    while file.size() > 1:
        for i in range(Max):
            bobo=fila.dequeue()
            file.enqueue(bobo)
        file.dequeue()
    return fila.dequeue()

# %%
# Teste
lista = ['jose', 'pedro', 'ana','margarida', 'fabio']
print(batata_quente(list, 5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Teste
#       2 lista = ['jose', 'pedro', 'ana','margarida', 'fabio']
# ----> 3 print(batata_quente(list, 5))
#
# NameError: name 'batata_quente' is not defined

# %%
#Perfeito — esse enunciado está bem clássico de **estrutura de dados com fila** 👏
Vou te guiar **passo a passo**, construindo o código sem “entregar tudo de uma vez”, exatamente como você pediu.

---

# 🧠 1. Entendendo a lógica do exercício

Você precisa simular:

1. Crianças em círculo → usar **fila**
2. Passar a batata → **remove do início e coloca no final**
3. Após `MAX` passes → **remove quem está no início (eliminado)**
4. Repetir até sobrar 1

---

# 🛠️ 2. Escolhendo a estrutura correta

Use `deque`, pois ele é ideal para fila:

```python
from collections import deque
```

---

# 🧩 3. Criando a função principal

Comece com:

```python
def batata_quente(criancas, max_passes):
    pass
```

📌 Parâmetros:

* `criancas` → lista de nomes
* `max_passes` → número de vezes que a batata é passada

---

# 🔄 4. Transformando a lista em fila

Dentro da função:

```python
fila = deque(criancas)
```

Agora cada criança está na fila (simulando o círculo).

---

# 🔁 5. Criando o loop principal

O jogo só termina quando sobrar 1:

```python
while len(fila) > 1:
```

---

# 🔃 6. Simulando o “passar a batata”

Agora vem a parte mais importante:

```python
for i in range(max_passes):
    pessoa = fila.popleft()
    fila.append(pessoa)
```

📌 O que isso faz:

* Remove do início (quem está com a batata)
* Coloca no final (passou para o próximo)

👉 Isso simula o movimento circular

---

# ❌ 7. Eliminando a criança

Depois dos passes:

```python
eliminado = fila.popleft()
print("Saiu da roda:", eliminado)
```

👉 Essa é a criança que “queimou” 🔥

---

# 🔍 8. (Opcional) Mostrar o estado da fila

Ajuda muito para entender:

```python
print("Fila atual:", list(fila))
```

---

# 🏆 9. Quando o loop terminar

Quando sobrar só uma criança:

```python
return fila[0]
```

👉 Essa é a vencedora 🎉

---

# 🧪 10. Preparando os dados (fora da função)

Você pode definir:

```python
criancas = ["Ana", "Bruno", "Carlos", "Diana", "Eduardo"]
max_passes = 3
```

---

# 🧱 11. Fluxo completo (em palavras)

Sem juntar tudo ainda, o algoritmo é:

1. Criar fila com os nomes
2. Enquanto houver mais de 1 criança:

   * Repetir `max_passes` vezes:

     * tirar do início e colocar no final
   * remover a criança do início (eliminada)
3. Retornar a última criança

---

# ⚠️ Erros comuns (importante!)

* ❌ Usar `pop()` → remove do final (errado)
* ❌ Esquecer `append()` → quebra o ciclo
* ❌ Usar lista comum → fica lento com `.pop(0)`

---

# 🚀 Se quiser melhorar depois

Posso te ajudar a:

* transformar em programa interativo (`input`)
* mostrar rodada por rodada com animação
* implementar usando **classe (POO)**
* desenhar o fluxo com diagrama

Só falar 👍
