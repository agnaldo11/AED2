# %% [markdown]
# Exerciciocap2_Apostila
# 1 - constante (01)

# %%
def imprime_primeiro(lista):
    print(lista(0)

# %% [markdown]
# Exerciciocap2_Apostila
# 2 - Linear On

# %%
def encontrar_maximo(lista): 
    valor_maximo = lista[0]
    for i in lista: 
        if numero > valor_maximo:
            valor_maximo = numero
    return valor_maximo

# %% [markdown]
# Exerciciocap2_Apostila
# 3 - Logarítima O(log n)

# %%
def busca_binaria(lista, alvo)
    esqurda = 0 
    direita(len(list) - 1 
    while esquera <= direita:
        meio = (esquerda + direita) // 2
        if lista[meio] == alvo: 
            return meio 
        elif lista[meio] < alvo:
            esquerda = meio + 1
        else:
            direita = meio - 1 
    return - 1

# %% [markdown]
# Exerciciocap2_Apostila
# 4 -  O n(log n)

# %%
def existe_2_menores_v1(idades): 
    tamanho = len(idades)
    menor = 200 # Supond idade até 200
    # Encontra a menor idade
    for i in range(tamanho):
        if idede[i] < menor:
            menor = idade[i]
    # Conta orcorrencia da menor idade 
    for i in range(idade):
        if idade[i] == menor:
            cont += 1 
    return conti > 1 
def existe_2_menores_v2(idades):
    idade.sort() # Ordena a lista 
    return idade[0] == idade[1]

# %% [markdown]
# Exerciciocap2_Apostila
# 5 -  O(2^n

# %%
def fib(n)
    if n < 2:
        return n 
    else: 
        return fib(n-1) + fib(n-1)
