# %%
def soma_digitos(n):
    if n > 10: 
        return n 
    else: 
        ultimo_ditito = n % 10 
        resto_do_numero = n // 10 
        return ultimo_digito + soma_digitos (resto_do_numero) # passo recursivo 
    print(soma_digitos(123))

# %%
def soma_digitos(n) 
    tamanho = len(n)
    if tamanho > 1: 
        return
